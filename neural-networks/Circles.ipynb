# %%
# %matplotlib inline

import sklearn.datasets
import matplotlib.pyplot as plt
import numpy as np
from boundary import *

# %%
np.random.seed(0)
X, Y = sklearn.datasets.make_circles(200, noise=1e-2)
plt.scatter(X[:,0], X[:,1], s=40, c=Y, cmap=plt.cm.Spectral)

# %%
from dynet import *

# %%
lr_model = Model()

pW = lr_model.add_parameters((1,2))
pb = lr_model.add_parameters((1))

renew_cg()

W = parameter(pW)
b = parameter(pb)

x = vecInput(2)

output = logistic(W*x + b)
y = scalarInput(0)
loss = binary_log_loss(output, y)

trainer = SimpleSGDTrainer(lr_model)

# %%
n_epochs = 100

for epoch in range(n_epochs):
    total_loss = 0
    seen = 0
    for (x_i, y_i) in zip(X, Y):
        x.set(x_i)
        y.set(y_i)
        seen += 1
        total_loss += loss.value()
        loss.backward()
        trainer.update()
    
    if epoch != 0:
        print("epoch %d average loss: %.4f" % (epoch, total_loss / seen))
# Out:
# epoch 1 average loss: 0.7147
# epoch 2 average loss: 0.7148
# epoch 3 average loss: 0.7149
# epoch 4 average loss: 0.7150
# epoch 5 average loss: 0.7150
# epoch 6 average loss: 0.7150
# epoch 7 average loss: 0.7150
# epoch 8 average loss: 0.7150
# epoch 9 average loss: 0.7150
# epoch 10 average loss: 0.7150
# epoch 11 average loss: 0.7150
# epoch 12 average loss: 0.7150
# epoch 13 average loss: 0.7150
# epoch 14 average loss: 0.7150
# epoch 15 average loss: 0.7150
# epoch 16 average loss: 0.7150
# epoch 17 average loss: 0.7150
# epoch 18 average loss: 0.7150
# epoch 19 average loss: 0.7150
# epoch 20 average loss: 0.7150
# epoch 21 average loss: 0.7150
# epoch 22 average loss: 0.7150
# epoch 23 average loss: 0.7150
# epoch 24 average loss: 0.7150
# epoch 25 average loss: 0.7150
# epoch 26 average loss: 0.7150
# epoch 27 average loss: 0.7150
# epoch 28 average loss: 0.7150
# epoch 29 average loss: 0.7150
# epoch 30 average loss: 0.7150
# epoch 31 average loss: 0.7150
# epoch 32 average loss: 0.7150
# epoch 33 average loss: 0.7150
# epoch 34 average loss: 0.7150
# epoch 35 average loss: 0.7150
# epoch 36 average loss: 0.7150
# epoch 37 average loss: 0.7150
# epoch 38 average loss: 0.7150
# epoch 39 average loss: 0.7150
# epoch 40 average loss: 0.7150
# epoch 41 average loss: 0.7150
# epoch 42 average loss: 0.7150
# epoch 43 average loss: 0.7150
# epoch 44 average loss: 0.7150
# epoch 45 average loss: 0.7150
# epoch 46 average loss: 0.7150
# epoch 47 average loss: 0.7150
# epoch 48 average loss: 0.7150
# epoch 49 average loss: 0.7150
# epoch 50 average loss: 0.7150
# epoch 51 average loss: 0.7150
# epoch 52 average loss: 0.7150
# epoch 53 average loss: 0.7150
# epoch 54 average loss: 0.7150
# epoch 55 average loss: 0.7150
# epoch 56 average loss: 0.7150
# epoch 57 average loss: 0.7150
# epoch 58 average loss: 0.7150
# epoch 59 average loss: 0.7150
# epoch 60 average loss: 0.7150
# epoch 61 average loss: 0.7150
# epoch 62 average loss: 0.7150
# epoch 63 average loss: 0.7150
# epoch 64 average loss: 0.7150
# epoch 65 average loss: 0.7150
# epoch 66 average loss: 0.7150
# epoch 67 average loss: 0.7150
# epoch 68 average loss: 0.7150
# epoch 69 average loss: 0.7150
# epoch 70 average loss: 0.7150
# epoch 71 average loss: 0.7150
# epoch 72 average loss: 0.7150
# epoch 73 average loss: 0.7150
# epoch 74 average loss: 0.7150
# epoch 75 average loss: 0.7150
# epoch 76 average loss: 0.7150
# epoch 77 average loss: 0.7150
# epoch 78 average loss: 0.7150
# epoch 79 average loss: 0.7150
# epoch 80 average loss: 0.7150
# epoch 81 average loss: 0.7150
# epoch 82 average loss: 0.7150
# epoch 83 average loss: 0.7150
# epoch 84 average loss: 0.7150
# epoch 85 average loss: 0.7150
# epoch 86 average loss: 0.7150
# epoch 87 average loss: 0.7150
# epoch 88 average loss: 0.7150
# epoch 89 average loss: 0.7150
# epoch 90 average loss: 0.7150
# epoch 91 average loss: 0.7150
# epoch 92 average loss: 0.7150
# epoch 93 average loss: 0.7150
# epoch 94 average loss: 0.7150
# epoch 95 average loss: 0.7150
# epoch 96 average loss: 0.7150
# epoch 97 average loss: 0.7150
# epoch 98 average loss: 0.7150
# epoch 99 average loss: 0.7150

# %%
plot_decision_boundary(x, output, X, Y)
